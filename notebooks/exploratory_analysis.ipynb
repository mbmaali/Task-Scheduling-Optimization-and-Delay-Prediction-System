# %% [markdown]
# # Workflow Exploratory Analysis
#
# This notebook shows the beginner-friendly workflow used in the project: load the dataset, clean it, engineer features, and generate the EDA report and figures.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT

# %%
from src.data_preprocessing import load_workflow_data, clean_workflow_data, print_data_summary
from src.feature_engineering import create_derived_features
from src.exploratory_analysis import perform_exploratory_analysis, compute_kpis

raw_df = load_workflow_data(PROJECT_ROOT / 'data' / 'workflow_data.csv')
clean_df = clean_workflow_data(raw_df)
workflow_df = create_derived_features(clean_df)
summary = print_data_summary(workflow_df)
summary

# %%
eda_results = perform_exploratory_analysis(
    workflow_df,
    figures_dir=PROJECT_ROOT / 'outputs' / 'figures',
    reports_dir=PROJECT_ROOT / 'outputs' / 'reports',
)
compute_kpis(workflow_df)

# %% [markdown]
# ## Next Step
#
# After this notebook, run `python main.py` from the project root to train the prediction models, optimize assignments, and generate the final reports.
